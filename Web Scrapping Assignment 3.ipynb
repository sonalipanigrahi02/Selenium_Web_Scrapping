# %% [markdown]
# Web Scraping Assignment-3
# Name: Sonali Panigrahi
# Batch: 2306
# Questions:
# 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitar

# %%
pip install chromedriver
# Out:
# Collecting chromedriver
#   Downloading chromedriver-2.24.1-py2.py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 6.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: chromedriver
# Successfully installed chromedriver-2.24.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install webdrivermanager
# Out:
# Collecting webdrivermanager
#   Downloading webdrivermanager-0.10.0.tar.gz (33 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in ./anaconda3/lib/python3.10/site-packages (from webdrivermanager) (2.28.1)
# Requirement already satisfied: tqdm in ./anaconda3/lib/python3.10/site-packages (from webdrivermanager) (4.64.1)
# Requirement already satisfied: BeautifulSoup4 in ./anaconda3/lib/python3.10/site-packages (from webdrivermanager) (4.11.1)
# Requirement already satisfied: appdirs in ./anaconda3/lib/python3.10/site-packages (from webdrivermanager) (1.4.4)
# Requirement already satisfied: lxml in ./anaconda3/lib/python3.10/site-packages (from webdrivermanager) (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.10/site-packages (from BeautifulSoup4->webdrivermanager) (2.3.2.post1)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests->webdrivermanager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests->webdrivermanager) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests->webdrivermanager) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests->webdrivermanager) (2022.12.7)
# Building wheels for collected packages: webdrivermanager
#   Building wheel for webdrivermanager (pyproject.toml) ... done
#   Created wheel for webdrivermanager: filename=webdrivermanager-0.10.0-py2.py3-none-any.whl size=19521 sha256=4585edb3430ff74a7db77cf7a27cf19cabdb9387ce74ba21add1edbbd640428f
#   Stored in directory: /Users/sonali/Library/Caches/pip/wheels/ae/15/2d/36d8ab7675e826df7b298c310a2c556d11150c88f64c8ca576
# Successfully built webdrivermanager
# Installing collected packages: webdrivermanager
# Successfully installed webdrivermanager-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdrivermanager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
#opening the website page
driver.get("https://www.amazon.in/")

# %%
val= input("Enter your item: ")
#entering product to be searched:
product = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
product.send_keys(val)

search = driver.find_element(By.ID,"nav-search-submit-button")
search.click()
# Out:
# Enter your item: Guitar

# %% [markdown]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "BrandName", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
#fetching all the product urls from first 3 pages
products_url=[]

start=0
end=3

#For looping in 3 Pages
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        products_url.append(i.get_attribute('href'))
    next_button = driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[67]/div/div/span/a[3]')
    time.sleep(3)

# %%
#Extracting details of each product from the links
BrandName =[]
Name_of_the_Product=[]
Price=[]
Return_Exchange=[]
Expected_Delivery=[]
Availability=[]

for product in products_url:
    driver.get(product)
    time.sleep(3)
    
    #extracting Brand name
    try:
        brand=driver.find_element(By.XPATH,'//span[@class="a-size-base po-break-word"]')
        BrandName.append(brand.text)
    except NoSuchElementException:
        BrandName.append('-')
        
    #Extracting Name_of_the_Product
    try:
        name=driver.find_element(By.XPATH,'//h1[@class="a-size-large a-spacing-none"]')
        Name_of_the_Product.append(name.text)
    except NoSuchElementException:
        Name_of_the_Product.append('-')
        
    #Extracting Price
    try:
        rate=driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
        Price.append(rate.text)
    except NoSuchElementException:
        Price.append('-')
        
    #Extracting Return/Exchange
    try:
        Policy =driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[24]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/span')
        Return_Exchange.append(Policy.text)
    except NoSuchElementException:
        Return_Exchange.append('-')
        
    #extracting expected delivery
    try:
        delivery = driver.find_element(By.XPATH,'//span[@class="a-text-bold"]')
        Expected_Delivery.append(delivery.text)
    except NoSuchElementException:
        Expected_Delivery.append('-')
        
    #Extracting Availabilty details
    try:
        available = driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        Availability.append(available.text)
    except NoSuchElementException:
        Availability.append('-')
        
print(len(BrandName),len(Name_of_the_Product),len(Price),len(Return_Exchange),len(Expected_Delivery),len(Availability),len(products_url))
driver.close()

guitar=pd.DataFrame({})
guitar['Brand']= BrandName
guitar['ProductName']= Name_of_the_Product
guitar['Return/Exchange']= Return_Exchange
guitar['Expected Delivery']= Expected_Delivery
guitar['Availability']= Availability
guitar['url']= products_url
guitar
# Out:
# 183 183 183 183 183 183 183
#           Brand                                        ProductName  \
# 0       Kadence  Kadence rosewood Guitar Frontier Series, Elect...
# 1       Kadence  Kadence Frontier guitar with Online Guitar lea...
# 2        Henrix  Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...
# 3         VAULT  Vault DA20 Dreadnought Acoustic Guitar With Gi...
# 4        JUAREZ  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
# ..          ...                                                ...
# 178    Medellin  Medellin Acoustic Guitar (with guitar learning...
# 179    IMAGINEA  Imaginea® 41 Inch Guitar 3TS Sunburst Beautifu...
# 180  Guitar Bro  GUITAR BRO - COMBO (Blue Acoustic Guitar for B...
# 181       VAULT  Vault Traveller 34 Inch Acoustic Guitar With T...
# 182    Sunburst  Imaginea® 41 Inch Guitar 3TS Sunburst Cutaway ...
#
#         Return/Exchange    Expected Delivery Availability  \
# 0    7 days Replacement  Saturday, 19 August     In stock
# 1    7 days Replacement  Saturday, 19 August     In stock
# 2    7 days Replacement    Sunday, 20 August     In stock
# 3    7 days Replacement    Sunday, 20 August     In stock
# 4    7 days Replacement   Tuesday, 22 August     In stock
# ..                  ...                  ...          ...
# 178  7 days Replacement   Tuesday, 22 August     In stock
# 179  7 days Replacement       12 - 22 August     In stock
# 180                   -       16 - 19 August     In stock
# 181  7 days Replacement    Sunday, 20 August     In stock
# 182  7 days Replacement   Tuesday, 22 August     In stock
#
#                                                    url
# 0    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 1    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 2    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 3    https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 4    https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..                                                 ...
# 178  https://www.amazon.in/Medellin-Acoustic-Guitar...
# 179  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 180  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 181  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
# 182  https://www.amazon.in/sspa/click?ie=UTF8&spc=M...
#
# [183 rows x 6 columns]

# %%
#Saving the DataFrame as csv.
guitar.to_csv('guitar.csv')

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By 
import requests

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdrivermanager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
def googlesearch(keyword):
    
    # opening the website page
    driver.get("https://images.google.com/")
    
    # Accessing the Search bar:
    input = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
    input.send_keys(keyword)
    
    #searching
    search = driver.find_element(By.XPATH,'//button[@class="Tg7LZd"]')
    search.click()
    
    #Scraping the first 10 image results
    for _ in range(20):
        driver.execute_script("window.scrollBy(0,1000)")
        
    images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
    image_url=[]
    image_data=[]
    
    for image in images:
        source=image.get_attribute('src')
        if source is not None:
            if(source[0:4] == 'http'):
                image_url.append(source)
                
    for i in range(len(image_url)):
        if i>10:
            break
        print("Downloading {0} of {1} images" .format(i, 10))
        response = requests.get(image_url[i])
        file=open(r"C:\Users\Rima Das\OneDrive\Desktop\images" +str(i)+".jpg","wb")
        file.write(response.content)

# %%
googlesearch('fruits')

# %%
googlesearch('cars')

# %%
googlesearch('Machine Learning')

# %%
googlesearch('Guitar')

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdrivermanager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
def smartphone(phone):
    #opening the website page
    driver.get("https://www.flipkart.com/")
    
    try:
        login=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
        login.click()
    except NoSuchElementException:
        print('Exception Raised', '(No popup to close)')
        
    # Entering Input and search
    input = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/div/input')
    input.send_keys(phone+' smartphone')
    
    search = driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/button')
    search.click()
    
    #creating emptylist
    Brand=[]
    SmartphoneName=[]
    Colour=[]
    RAM = []
    storage = []
    primary_camera = []
    secondary_camera = []
    display_size = []
    battery = []
    price  = []
    product_url = []
    
    #Extracting Brandname and Phone Name
    brandtags = driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
    for brand in brandtags:
        Brand.append(brand.text.split()[0])
        time.sleep(1)
        SmartphoneName.append(brand.text)
    
    # Extracting Color
    cr =[color.text for color in brandtags]
    import re
    pattern = r"\((.*?), \d+ GB\)"
    extracted_text = [re.findall(pattern, i)[0] for i in cr]
    for content in extracted_text:
        Colour.append(content)
        
    # Extracted RAM & ROM
    ram = driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][1]')
    for i in ram:
        RAM.append(i.text.split('|')[0])
        
    rom = driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][1]')    
    for i in rom:
        split_result = i.text.split('|')
        if len(split_result) > 1:
            storage.append(split_result[1].strip())
        else:
            storage.append('N/A')
            
    #Extracting primary_camera & Secondary_camera
    camera = driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][3]')
    for i in camera:
        primary_camera.append(i.text.split('|')[0])
        split_result = i.text.split('|')
        if len(split_result) > 1:
            secondary_camera.append(split_result[1].strip().split()[0])
        else:
            secondary_camera.append('N/A')
    
    #Extracting display size
    display = driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][2]')
    for i in display:
        display_size.append(i.text)
        
    #Extracting battery
    batteryDetails = driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][4]')
    for i in batteryDetails:
        battery.append(i.text)
        
    # Extracting Price
    Rate = driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
    for i in Rate:
        price.append(i.text)
    
    # Extracting Product url
    url = driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
    for i in url:
        product_url.append(i.get_attribute('href'))
        
    #creating DataFrame
    smartphone_data = pd.DataFrame({})
    smartphone_data["Brand Name"]= Brand
    smartphone_data["Smartphone name"]= SmartphoneName
    smartphone_data["Colour"]= RAM
    smartphone_data["RAM"]= SmartphoneName
    smartphone_data["Primary Camera"]= primary_camera
    smartphone_data["Secondary Camera"]= secondary_camera
    smartphone_data["Display Size"]= display_size
    smartphone_data["Battery Capacity"]= battery
    smartphone_data["Price"]= price
    smartphone_data["Product Url"]= product_url
    
    return smartphone_data

# %%
Phone = smartphone('Oneplus Nord')
Phone
# Out:
# Exception Raised (No popup to close)
#    Brand Name                                    Smartphone name      Colour  \
# 0     OnePlus                    OnePlus Nord (Gray Onyx, 64 GB)   6 GB RAM
# 1     OnePlus      OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)   6 GB RAM
# 2     OnePlus     OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)   6 GB RAM
# 3     OnePlus           OnePlus Nord 3 5G (Tempest Gray, 256 GB)  16 GB RAM
# 4     OnePlus            OnePlus Nord 3 5G (Misty Green, 128 GB)   8 GB RAM
# 5     OnePlus            OnePlus Nord 3 5G (Misty Green, 256 GB)  16 GB RAM
# 6     OnePlus           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)   8 GB RAM
# 7     OnePlus              OnePlus Nord 2T 5G (Jade Fog, 128 GB)   8 GB RAM
# 8     OnePlus           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)   8 GB RAM
# 9     OnePlus    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)   8 GB RAM
# 10    OnePlus  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...   8 GB RAM
# 11    OnePlus           OnePlus Nord 3 5G (Tempest Gray, 128 GB)   8 GB RAM
# 12    OnePlus    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)   8 GB RAM
# 13    OnePlus  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...   8 GB RAM
# 14    OnePlus           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)   8 GB RAM
# 15    OnePlus              OnePlus Nord 2T 5G (Jade Fog, 128 GB)   8 GB RAM
# 16    OnePlus            OnePlus Nord 2 5G (Gray Sierra, 128 GB)   8 GB RAM
# 17    OnePlus              OnePlus Nord 2 5G (Blue Haze, 256 GB)  12 GB RAM
# 18    OnePlus             OnePlus Nord CE 5G (Blue Void, 256 GB)  12 GB RAM
# 19    OnePlus              OnePlus Nord 2T 5G (Jade Fog, 128 GB)   8 GB RAM
# 20    OnePlus         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)   8 GB RAM
# 21    OnePlus      OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)   8 GB RAM
# 22    OnePlus                OnePlus Nord 2 5G (PAC-MAN, 256 GB)  12 GB RAM
# 23    OnePlus                   OnePlus Nord (Gray Onyx, 128 GB)   8 GB RAM
#
#                                                   RAM     Primary Camera  \
# 0                     OnePlus Nord (Gray Onyx, 64 GB)        48MP + 8MP
# 1       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  64MP Rear Camera
# 2      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  64MP Rear Camera
# 3            OnePlus Nord 3 5G (Tempest Gray, 256 GB)   50MP Rear Camera
# 4             OnePlus Nord 3 5G (Misty Green, 128 GB)   50MP Rear Camera
# 5             OnePlus Nord 3 5G (Misty Green, 256 GB)   50MP Rear Camera
# 6            OnePlus Nord 2T 5G (Gray Shadow, 128 GB)   50MP Rear Camera
# 7               OnePlus Nord 2T 5G (Jade Fog, 128 GB)  50MP Rear Camera
# 8            OnePlus Nord 2T 5G (Gray Shadow, 128 GB)  50MP Rear Camera
# 9     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)  108MP Rear Camera
# 10  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 128...  108MP Rear Camera
# 11           OnePlus Nord 3 5G (Tempest Gray, 128 GB)   50MP Rear Camera
# 12    OnePlus Nord CE 3 Lite 5G (Pastel Lime, 128 GB)  108MP Rear Camera
# 13  OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...  108MP Rear Camera
# 14           OnePlus Nord 2T 5G (Gray Shadow, 128 GB)   50MP Rear Camera
# 15              OnePlus Nord 2T 5G (Jade Fog, 128 GB)   50MP Rear Camera
# 16            OnePlus Nord 2 5G (Gray Sierra, 128 GB)   50MP Rear Camera
# 17              OnePlus Nord 2 5G (Blue Haze, 256 GB)   50MP Rear Camera
# 18             OnePlus Nord CE 5G (Blue Void, 256 GB)   64MP Rear Camera
# 19              OnePlus Nord 2T 5G (Jade Fog, 128 GB)   50MP Rear Camera
# 20         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)   50MP Rear Camera
# 21      OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)   64MP Rear Camera
# 22                OnePlus Nord 2 5G (PAC-MAN, 256 GB)   50MP Rear Camera
# 23                   OnePlus Nord (Gray Onyx, 128 GB)        48MP + 8MP
#
#    Secondary Camera                           Display Size  Battery Capacity  \
# 0              32MP  16.36 cm (6.44 inch) Full HD+ Display  4115 mAh Battery
# 1              16MP           16.74 cm (6.59 inch) Display  5000 mAh Battery
# 2              16MP           16.74 cm (6.59 inch) Display  5000 mAh Battery
# 3               N/A           17.12 cm (6.74 inch) Display  5000 mAh Battery
# 4               N/A           17.12 cm (6.74 inch) Display  5000 mAh Battery
# 5               N/A           17.12 cm (6.74 inch) Display  5000 mAh Battery
# 6               N/A            17.02 cm (6.7 inch) Display  4500 mAh Battery
# 7              32MP            17.02 cm (6.7 inch) Display  4500 mAh Battery
# 8              32MP            17.02 cm (6.7 inch) Display  4500 mAh Battery
# 9               N/A           17.07 cm (6.72 inch) Display  5000 mAh Battery
# 10              N/A           17.07 cm (6.72 inch) Display  5000 mAh Battery
# 11              N/A           17.12 cm (6.74 inch) Display  5000 mAh Battery
# 12              N/A           17.07 cm (6.72 inch) Display  5000 mAh Battery
# 13              N/A           17.07 cm (6.72 inch) Display  5000 mAh Battery
# 14              N/A            17.02 cm (6.7 inch) Display  4500 mAh Battery
# 15              N/A            17.02 cm (6.7 inch) Display  4500 mAh Battery
# 16              N/A           16.33 cm (6.43 inch) Display  4500 mAh Battery
# 17              N/A           16.33 cm (6.43 inch) Display  4500 mAh Battery
# 18              N/A           16.33 cm (6.43 inch) Display  4500 mAh Battery
# 19              N/A            17.02 cm (6.7 inch) Display  4500 mAh Battery
# 20              N/A           16.33 cm (6.43 inch) Display  4500 mAh Battery
# 21              N/A           16.74 cm (6.59 inch) Display  5000 mAh Battery
# 22              N/A           16.33 cm (6.43 inch) Display  4500 mAh Battery
# 23             32MP  16.36 cm (6.44 inch) Full HD+ Display  4115 mAh Battery
#
#       Price                                        Product Url
# 0   ₹23,990  https://www.flipkart.com/oneplus-nord-gray-ony...
# 1   ₹17,780  https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 2   ₹17,688  https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 3   ₹37,233  https://www.flipkart.com/oneplus-nord-3-5g-tem...
# 4   ₹32,781  https://www.flipkart.com/oneplus-nord-3-5g-mis...
# 5   ₹37,470  https://www.flipkart.com/oneplus-nord-3-5g-mis...
# 6   ₹28,993  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 7   ₹28,999  https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 8   ₹28,970  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 9   ₹21,999  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 10  ₹19,999  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 11  ₹32,801  https://www.flipkart.com/oneplus-nord-3-5g-tem...
# 12  ₹19,999  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 13  ₹21,999  https://www.flipkart.com/oneplus-nord-ce-3-lit...
# 14  ₹28,900  https://www.flipkart.com/oneplus-nord-2t-5g-gr...
# 15  ₹28,995  https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 16  ₹29,999  https://www.flipkart.com/oneplus-nord-2-5g-gra...
# 17  ₹34,990  https://www.flipkart.com/oneplus-nord-2-5g-blu...
# 18  ₹27,999  https://www.flipkart.com/oneplus-nord-ce-5g-bl...
# 19  ₹28,999  https://www.flipkart.com/oneplus-nord-2t-5g-ja...
# 20  ₹24,999  https://www.flipkart.com/oneplus-nord-ce-2-5g-...
# 21  ₹21,999  https://www.flipkart.com/oneplus-nord-ce-2-lit...
# 22  ₹37,999  https://www.flipkart.com/oneplus-nord-2-5g-pac...
# 23  ₹24,990  https://www.flipkart.com/oneplus-nord-gray-ony...

# %%
#Saving to csv
Phone.to_csv('onePlussmartphone.csv')

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdrivermanager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

import re

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
#opening the website page
driver.get("https://www.google.com/maps")

city = driver.find_element(By.XPATH,'//input[@class="searchboxinput xiQnY"]')
city.send_keys('Delhi')

search = driver.find_element(By.XPATH,'//button[@id="searchbox-searchbutton"]')
search.click()

# %%
try:
    url_str = driver.current_url
    #print("URL Extracted: ", url_str)
    latitude_longitude = re.findall(r'@(.*)data',url_str)
    if len(latitude_longitude):
        lat_lng_list = latitude_longitude[0].split(",")
        if len(lat_lng_list)>=2:
            latitude = lat_lng_list[0]
            longitude = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(latitude, longitude))
except Exception as e:
        print("Error: ", str(e))
        
driver.close()
# Out:
# Latitude = 19.1591583, Longitude = 73.0523224

# %% [markdown]
# 6. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdrivermanager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
#opening the website
driver.get("https://www.digit.in/")

# %%
laptop = driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]')
laptop.click()

best = driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/div[2]/div/div[1]/span[4]')
best.click()

gaming =driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/div[2]/div/div[5]/div/div[2]')
gaming.click()

# %%
#extracting All the Laptop url
producturl=[i.get_attribute('data-href') for i in driver.find_elements(By.XPATH,'//span[@class="datahreflink"]')[:7]]

#Creating Emptylist to extract required details
brand=[]
model=[]
os=[]
display=[]
processor=[]
storage=[]
memory=[]
launch_date=[]
price=[]

for i in producturl:
    driver.get(i)
    time.sleep(6)
    
    #Extracting Brand
    try:
        for i in driver.find_elements(By.XPATH,'/html/body/div[7]/div[2]/div[3]/div[2]/div[1]/div[3]/strong'):
            brand.append(i.text)
    except NoSuchElementException:
        brand.append('-')
    
    #Extracting Product Name
    try:
        for i in driver.find_elements(By.XPATH,'//div[@class="heading-wraper"]/h1'):
            model.append(i.text)
    except NoSuchElementException:
        model.append('-')
        
    #Extracting Os
    try:
        for i in driver.find_elements(By.XPATH,'/html/body/div[7]/div[2]/div[3]/div[2]/div[3]/div/ul/li[1]/div/p[2]'):
            os.append(i.text)
    except NoSuchElementException:
        os.append('-')
        
    #Extracting display
    try:
        for i in driver.find_elements(By.XPATH,'/html/body/div[7]/div[2]/div[3]/div[2]/div[3]/div/ul/li[2]/div/p[2]/strong'):
            display.append(i.text)
    except NoSuchElementException:
        display.append('-')
        
    #Extracting Processor
    try:
        for i in driver.find_elements(By.XPATH,'/html/body/div[7]/div[2]/div[3]/div[2]/div[3]/div/ul/li[3]/div/p[2]'):
            processor.append(i.text)
    except NoSuchElementException:
        processor.append('-')
        
    #Extracting memory
    try:
        items = driver.find_elements(By.XPATH, '//div[@class="specs_details "]/ul')
        item = driver.find_elements(By.XPATH, '/li[4]/div/p/strong')
        for item in items:
            memory.append(item.text.split('\n')[-1])
    except Exception:
        memory.append('-')
        
    #Extracting Release date
    try:
        for i in driver.find_elements(By.XPATH,'/html/body/div[7]/div[2]/div[3]/div[2]/div[1]/div[2]/strong'):
            launch_date.append(i.text)
    except NoSuchElementException:
        launch_date.append('-')
        
    #Extracting Price
    try:
        for i in driver.find_elements(By.XPATH,'/html/body/div[7]/div[2]/div[3]/div[2]/div[4]/div/h2/strong'):
            price.append(i.text)
    except NoSuchElementException:
        price.append('-')
        
driver.close()
        
print(len(brand),
      len(model),
      len(os),
      len(display),
      len(processor),
      len(memory),
      len(launch_date),
      len(price))

BestGamingLaptop=pd.DataFrame({
    "Brand":brand,
    "Model":model,
    "OS":os,
    "Display":display,
    "Processor":processor,
    "Memory":memory,
    "Launch Date":launch_date,
    "Price": price
})
# Out:
# 7 7 7 7 7 7 7 7

# %%
BestGamingLaptop
# Out:
#     Brand                                              Model               OS  \
# 0      HP       HP Omen 17-ck2008TX 13th Gen Core i7-13700HX  Windows 11 Home
# 1     MSI  MSI GT77 Titan 12UHS-054IN 12th Gen Core i9-12...  Windows 11 Home
# 2  Lenovo  Lenovo Legion 5i Pro 12th Gen Core i7-12700H (...  Windows 11 Home
# 3    Asus  ASUS ROG Strix Scar 18 G834JZ-N5041WS 13th Gen...  Windows 11 Home
# 4    Acer  Acer Predator Helios Neo 16 13th Gen Core i7-1...  Windows 11 Home
# 5    Asus  ASUS ROG Zephyrus G14 Ryzen 9-6900HS (GA402RJZ...  Windows 11 Home
# 6     MSI  MSI Cyborg 15 12th Gen Core i7-12650H (A12VF-2...  Windows 11 Home
#
#                Display                                 Processor  \
# 0  17.3" (2560 x 1440)  13th Gen Intel Core i7-13700HX | 5.0 GHz
# 1  17.3" (3840 x 2160)  12th Gen Intel Core i9-12900HX | 3.6 GHz
# 2    16" (2560 x 1600)   12th Gen Intel Core i7-12700H | 4.7 GHz
# 3    18" (1920 x 1200)  13th Gen Intel Core i9-13980HX | 2.2 GHz
# 4    16" (2560 x 1600)       13th Gen Intel Core i7-13700HX | NA
# 5    14" (1920 x 1200)              AMD Ryzen 9-6900HS | 4.9 GHz
# 6  15.6" (1920 x 1080)   12th Gen Intel Core i7-12650H | 4.7 GHz
#
#                 Memory   Launch Date      Price
# 0  1 TB SSD/16 GB DDR5  12 May, 2023  ₹ 269,777
# 1  2 TB SSD/64 GB DDR5  31 Oct, 2022  ₹ 499,990
# 2  1 TB SSD/32 GB DDR5  12 May, 2023  ₹ 218,000
# 3  1 TB SSD/32 GB DDR5  27 Mar, 2023  ₹ 279,990
# 4  1 TB SSD/16 GB DDR5  12 May, 2023  ₹ 149,990
# 5  1 TB SSD/16 GB DDR5  12 May, 2023  ₹ 156,990
# 6  1 TB SSD/16 GB DDR5  12 May, 2023  ₹ 130,990

# %% [markdown]
# 7. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# Importing Libraries
import pandas as pd
import selenium                                  
from bs4 import BeautifulSoup
from selenium import webdriver                   
from selenium.webdriver.common.by import By      

import warnings                                  
warnings.filterwarnings("ignore")

import time                                      
from webdrivermanager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

#Importing required exceptions which needs to be handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Let's Install automated chrome browser and connect it to web driver
driver = webdriver.Chrome(service=Service())

#maximise the window
driver.maximize_window()

# %%
# find on google ,https://www.forbes.com/ 
driver.get("https://www.forbes.com/")

# %%
Rank=[]
Name=[]
NetWorth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

#Extracting Rank
rank=driver.find_elements(By.XPATH,'//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in rank:
    Rank.append(i.text)
    time.sleep(1)
    
#Extracting Name
name = driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][2]')
for i in name:
    Name.append(i.text)
    time.sleep(1)
    
#Extracting Age
age=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][4]')
for i in age:
    Age.append(i.text)
    time.sleep(1)
    
#Extracting Net Worth
worth=driver.find_elements(By.XPATH,'//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
for i in worth:
    NetWorth.append(i.text)
    time.sleep(1)
        
#Extracting Country/Citizenship
city=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][5]')
for i in city:
    Citizenship.append(i.text)
    time.sleep(1)
    
#Extracting Source
source=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][6]')
for i in source:
    Source.append(i.text)
    time.sleep(1)
        
#Extracting Industry
industry=driver.find_elements(By.XPATH,'//div[@class="TableRow_cell__db-hv Table_cell__houv9"][7]')
for i in industry:
    Industry.append(i.text)
    time.sleep(1)
           
driver.close()

# Creating DataFrame:
billionaires =pd.DataFrame({'Rank': Rank, 'Name': Name,'Net Worth': NetWorth,'Age': Age,'Citizenship': Citizenship,'Source':Source,'Industry': Industry})
billionaires
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Net Worth, Age, Citizenship, Source, Industry]
# Index: []
